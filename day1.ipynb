# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# This is basic python

# %% [markdown]
# #### variable

# %% [markdown]
# ![image.png](attachment:0b3d2704-2dd7-4e05-930f-98d0a342c4e6.png)

# %%
# variable
# variable is a memory location which is used to store value
# python is a dynamic type of programming language

# %%
# comment >> used for documentation purpose
# information/notes purpose
# python interpreter ignores comment
# by using hash(#)

# %%
# Python is High level,general purpose,interactive and object oriented prog. lang.

# %%
# Any langauge can be high level or low level
# High level >> closer to human language >> Human readable format
# Python,Java,C++ ....


# Low level  >> closer to machine >> C,Assembly,Binary,Matlab >> fast

# %%
# Any language can be procedure oriented or object oriented 
# also may be both
# procedure oriented >> procedures >>> C
# BOTH  >>> Python,C++
# object oriented >> language which support for class and object >> Java

# %%
# Any language can be compiled or Interpreted
# also both
# compiled  >> Execution is done at a once  >> C  > fast
# both >> JAVA
# interpreted >> Execution is done line by line/ can execute one instruction at a time >> Python,R

# %%
# Any language can be static or Dynamic
# static typing >> compulsory to initialize variable first
# int a=77  ,float b=67.89
# C,C++,Java



# dynamic typing >>> No need of initialization of variable
# type checking is takes place at runtime
# a=44
# Python,R

# %%
# features of python


# simple/easy
# Free and open source
# portable /platform independent >> can install python software on any platform(Mac Windows  Linux)
# high level
# object oriented prog langauge
# expressive
# interactive 
# general purpose

# extensible >> if there is a need ,can write some python program in other language also 
# >> ex >>numpy >> python,C++

# interpreted >> execution is done line by line

# dynamic typing >>  type checking is takes place at runtime

# support for large set of std libraries>>  (library/module/package)>> library means prewitten code
# code written by someone else ,can use whenever we required  >> ex >>numpy pandas 


# supports for GUI(Grapical user interface) >> libraries >> tkinter,turtle django

# support for many databases MYSQL ORACLE >>>

# %%
# limitations

# slow 
# security low

# %%
# applications of python

# Machine learning
# AI
# Datascience
# Data Anaysis
# Business Analyst'
# Networking
# web devlopement
# data engineering
# gaming /animations/mobile apps

# %%
# important concepts 
# Python is case sensitive programming langauge
# no need of semicolon
# no need of curly braces  (block of code)  >>> indent in python
# Everything is an object in python

# %%
a = 3

# %%
b = 2.98

# %%
c= 23+3j

# %%
type(c)
# Out:
# complex

# %%
d='sj'

# %%
print(d)
# Out:
# sj

# %%
type(d)
# Out:
# str

# %%
# identifier
# naming system
# is a name use to identify variable,function, method, class oar any other object
# rules:
# A-Z , a-z , 0-9 , _(underscore)
# we cannot use special symbol , cannot use space , cannot start with digit , cannot use keywods as an identifiers

# %%
num1=33

# %%
num$=33
# Out:
#   Cell In[35], line 1
#     num$=33
#        ^
# SyntaxError: invalid syntax

# %%
roll no=33
# Out:
#   Cell In[37], line 1
#     roll no=33
#          ^
# SyntaxError: invalid syntax

# %%
roll_no=33

# %%
1num=33
# Out:
#   Cell In[41], line 1
#     1num=33
#     ^
# SyntaxError: invalid decimal literal

# %%
try=66
# Out:
#   Cell In[43], line 1
#     try=66
#        ^
# SyntaxError: expected ':'

# %%
# keywords
# special reserved words
# has special meaning
# 35 keywords in python
# all keywords are i lowercase except True , False and None

# %%
help('keywords')
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %%
# fuction/method/operator
# use o perforn specific task

# how to call function >> function_name(value/arguments/parameter)

# how to call method >> variable_name.method_name(arguments)

# how to use operator >> 4+6

# function is user for calculation purpose

# function/method/operator always return value >> means we have to store this value if we have to use it

# %%
# jupiter properties
# jupiter is use for inspection purpose also
# no need to print , no need to store value for inspection purpose
# is immediate mode >> get output immediately >> line by line

# %%
a=9

# %%
a
# Out:
# 9

# %%
print(a)
# Out:
# 9

# %%
len('shardul')
# Out:
# 7

# %%
l=len('jadhav')

# %%
l
# Out:
# 6

# %%
print(len('shardul'))
# Out:
# 7

# %%
6+4
# Out:
# 10

# %%
j=6+4

# %%
j
# Out:
# 10

# %%
f=12 # = is an assign symbol
g=13
result=f+g 
print(result)
# Out:
# 25

# %%
# Data Types

# Numeric data types
# 1) integer
# 2) float
# 3) complex

# 4) string
# 5) boolean
# 6) None

# 7) list
# 8) tuple
# 9) set
# 10) dictionary
# 11) range
# 12) array

# %%
# 1) integer
# whole number
# int is a  short name or internal name for a integer

# %%
a=12

# %%
a
# Out:
# 12

# %%
z=type(a)

# %%
z
# Out:
# int

# %%
# 2) float
# which contain decimal points

# %%
a=12.15

# %%
a
# Out:
# 12.15

# %%
type(a)
# Out:
# float

# %%
# 3) complex
# which contain real and imaginary part

# %%
c=12+7j

# %%
c
# Out:
# (12+7j)

# %%
type(c)
# Out:
# complex

# %%
# 4) string
# string is a container datatype
# collection of characters
# sequence of characters
# characters means anything >> alphabets , special symbols , space , digit ,etc
# by using single quote , double quote , triple quote
# str is short/internal name for string

# %%
name1='shardul'

# %%
name2="ram"

# %%
name3='''raju'''

# %%
name1
# Out:
# 'shardul'

# %%
type(name1)
# Out:
# str

# %%
a='s j'

# %%
b=' '

# %%
c='123'

# %%
b
# Out:
# ' '

# %%
a
# Out:
# 's j'

# %%
c
# Out:
# '123'

# %%
# concatenation

# %%
'ram'+'das'
# Out:
# 'ramdas'

# %%
'ram'+' '+'das'
# Out:
# 'ram das'

# %%
# repetation

# %%
'ram '*5
# Out:
# 'ram ram ram ram ram '

# %%
# use of triple quote
# multiline string
# multiline comment
# docsstring

# %%
# multiline string cannot write using single and double quote
a=''' i am from
 pune
 maharashtra'''

# %%
a
# Out:
# ' i am from\n pune\n maharashtra'

# %%
print(a)
# Out:
#  i am from
#  pune
#  maharashtra

# %%
# multiline commet
# by using #(single line comment)
# python dose not support multiline comment
# can use >> '''  '''

# %%
''' this is my
first
program'''
a=2
b=3
result=a+b
print(result)
# Out:
# 5

# %%
# 5) boolean
# True False

# %%
a=True

# %%
a
# Out:
# True

# %%
type(a)
# Out:
# bool

# %%
b=False

# %%
# comparison operator , logical operator >> returns output in boolean form

# %%
d=4>1

# %%
d
# Out:
# True

# %%
type(d)
# Out:
# bool

# %%
# 6) None
# nothing

# %%
a=None

# %%
a

# %%
type(a)
# Out:
# NoneType

# %%
# Container data type/collection data type
# container means which contain multiple values

# container
# list , tuple , set , dictionary , range , array , string

# non container
# int , float , complex , boolean

# %%
# 7)list
# list is a container which contain multiple values
# by using [ ]
# homogenous >> all values of same data type
# hetergenous >> mixed data type

# %%
list1=[1,3,5,2,6] #homogenous

# %%
list1
# Out:
# [1, 3, 5, 2, 6]

# %%
type(list1)
# Out:
# list

# %%
list2=[11,'sj',True,None] #hetrogenous

# %%
list2
# Out:
# [11, 'sj', True, None]

# %%
type(list2)
# Out:
# list

# %%
# 8) tuple
# tuple is a cntainer which contain multiple values
# by using ( )
# homogenous >> all values of same data type
# hetergenous >> mixed data type

# %%
tup1=(11,22,33,44,55,66) #homogenous

# %%
tup1
# Out:
# (11, 22, 33, 44, 55, 66)

# %%
type(tup1)
# Out:
# tuple

# %%
tup2=(11,'sj',True,None) #hetrogenious

# %%
tup2
# Out:
# (11, 'sj', True, None)

# %%
type(tup2)
# Out:
# tuple

# %%
# 9) set
# set is a cntainer which contain multiple values
# by ysing { }
# homogenous >> all values of same data type
# hetergenous >> mixed data type

# %%
set1={11,22,33,44}

# %%
set1
# Out:
# {11, 22, 33, 44}

# %%
type(set1)
# Out:
# set

# %%
#help(set) for internal structure

# %%
set2=(11,'sj',True,None) #hetrogenious

# %%
set2
# Out:
# (11, 'sj', True, None)

# %%
# 10) dictionary
# is also a container
# stores info in the form of key value pair
# represented by { : }

# %%
d1={1:21,2:33,3:34,4:44}

# %%
d1
# Out:
# {1: 21, 2: 33, 3: 34, 4: 44}

# %%
type(d1)
# Out:
# dict

# %%
d2={'roll':11,'name':'shardul','marks':88,'school':None,'isperent':True}

# %%
d2
# Out:
# {'roll': 11, 'name': 'shardul', 'marks': 88, 'school': None, 'isperent': True}

# %%
# 11) range
# 12) array
# see later

# %%
# copy one variable into another variable
# just assign it

# %%
a=12

# %%
a
# Out:
# 12

# %%
b=a

# %%
b
# Out:
# 12

# %%
# how to write multiple variable in a single line

# %%
a,b=12,13

# %%
a
# Out:
# 12

# %%
b
# Out:
# 13

# %%
a+b
# Out:
# 25

# %%
x,y,z=12,'raj',True

# %%
x
# Out:
# 12

# %%
y
# Out:
# 'raj'

# %%
z
# Out:
# True

# %%
# overwrite
# new value overwrite old value

# %%
a=12

# %%
a=33

# %%
a
# Out:
# 33

# %%
# swapping

# %%
a=12

# %%
b=13

# %%
temp=a #temp=12
a=b #a=13
b=temp #b=12

# %%
a
# Out:
# 13

# %%
b
# Out:
# 12

# %%
a,b=b,a # rot two method

# %%
a
# Out:
# 12

# %%
b
# Out:
# 13

# %%
# del keyword
# to delete variable from program memory
# also called as object destroyer

# %%
e=44
f=77

# %%
e
# Out:
# 44

# %%
f
# Out:
# 77

# %%
del e

# %%
e
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[163], line 1
# ----> 1 e
#
# NameError: name 'e' is not defined

# %%
# len function
# to get no. of items in a container
 # only on container datatype

# %%
len('shardul')
# Out:
# 7

# %%
c=len('shardul') # for editor

# %%
c
# Out:
# 7

# %%
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %%
len(1234) # len only on container datatype
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[181], line 1
# ----> 1 len(1234)
#
# TypeError: object of type 'int' has no len()

# %%
len('1234')
# Out:
# 4

# %%
# function as an identifier

# %%
print=22 # we have made print as an identifier

# %%
print
# Out:
# 22

# %%
print('hi')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[231], line 1
# ----> 1 print('hi')
#
# TypeError: 'int' object is not callable

# %%
del print #delete print

# %%
print('hi')
# Out:
# hi

# %%
# ASCII
# american standard code for info interchange
# each character has a unique value
# keybord has 256 characters

# %%
ord('A')
# Out:
# 65

# %%
ord('a')
# Out:
# 97

# %%
ord('/')
# Out:
# 47

# %%
chr(65)
# Out:
# 'A'

# %%
chr(47)
# Out:
# '/'

# %%
chr(32)
# Out:
# ' '

# %%
ord(' ')
# Out:
# 32

# %%
# id function
# to get memory address of variable

# %%
a=11

# %%
a
# Out:
# 11

# %%
id(a)
# Out:
# 140707554536184

# %%
# small integer caching
# -5 to 250 is the range
# for same value we get same memory location 
# saves memory

# %%
a=12
b=12
# they will point to same memory location
# only in python lang

# %%
id(a)
# Out:
# 140707554536216

# %%
id(b)
# Out:
# 140707554536216

# %%
# multiple statements on a single line
# use ;

# %%
a=12
b=13
result=a+b
print(result)
# Out:
# 25

# %%
a=12;b=13;result=a+b;print(result) # by multiple statements on a single line
# Out:
# 25

# %%
# typecasting
# the conversion of one data type into another data type
# has 2 types
# 1) implicit typecasting
# 2) explicit typecasting

# %%
# 1) implicit >> internal typecasting
# Typecasting is done but is done internally/automatically

# %%
4+3.5 # it converts internally and then add becouse one is int another in float
# Out:
# 7.5

# %%
5/2
# Out:
# 2.5

# %%
# 2) ecplicit >> external typecasting
# user involvement
# typecasting is done by user as per there requirements

# %%
# typecasting functions
# int(),load(),complex(),bool()
# list(),str(),tuple(),dict(),set()

# %%
a=[11,22,33]

# %%
b=tuple(a)

# %%
a
# Out:
# [11, 22, 33]

# %%
b
# Out:
# (11, 22, 33)

# %%
# typecasting rules
# 1) container to container
# 2) non container to non container
# 3) No rules to convert into string
# 4) can convert string into numeric

# %%
# 1) container to container .. exception dictionary

# %%
a='shardul'

# %%
list(a)
# Out:
# ['s', 'h', 'a', 'r', 'd', 'u', 'l']

# %%
tuple(a)
# Out:
# ('s', 'h', 'a', 'r', 'd', 'u', 'l')

# %%
list(a)
# Out:
# ['s', 'h', 'a', 'r', 'd', 'u', 'l']

# %%
a=[11,22,33,44,55]

# %%
dict(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 dict(a)
#
# TypeError: cannot convert dictionary update sequence element #0 to a sequence

# %%
list(a)
# Out:
# [11, 22, 33, 44, 55]

# %%
b=[[11,22],[33,44]]

# %%
dict(b)
# Out:
# {11: 22, 33: 44}

# %%
x=['a','b','c'] # in string it will convert as str is given

# %%
str(x)
# Out:
# "['a', 'b', 'c']"

# %%
# Non container to non container

# %%
a=12

# %%
a
# Out:
# 12

# %%
float(a)
# Out:
# 12.0

# %%
complex(a)
# Out:
# (12+0j)

# %%
b=33.89

# %%
int(b)
# Out:
# 33

# %%
float(b)
# Out:
# 33.89

# %%
complex(b)
# Out:
# (33.89+0j)

# %%
# No rules to convert into string

# %%
a=12

# %%
str(a)
# Out:
# '12'

# %%
str(33.45)
# Out:
# '33.45'

# %%
a={1:11,2:22}

# %%
str(a)
# Out:
# '{1: 11, 2: 22}'

# %%
# 4) can convert string into numeric

# %%
a='45'

# %%
int(a)
# Out:
# 45

# %%
b='23.44'

# %%
int(b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 int(b)
#
# ValueError: invalid literal for int() with base 10: '23.44'

# %%
float(b)
# Out:
# 23.44

# %%
#

# %%
a='avi'
b=123

# %%
a+b # b is an integer so it cannot be added in string, we have to convert it into string
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 a+b
#
# TypeError: can only concatenate str (not "int") to str

# %%
a+str(b)
# Out:
# 'avi123'
